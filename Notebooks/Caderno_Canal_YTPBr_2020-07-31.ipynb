# %% [markdown]
# ## Caderno YTPBR_2020-07-31
#
# Canais Poop - cheguei nesses canais observando em comentário de um vídeo de humor de Bolsonaro (Stand-up). Um dos comentários mais imacto feito por Richteru
#
# - Nos favoritos de Richteru, tem um poop YTPBR - Esta piada não foi muito boa...https://www.youtube.com/watch?v=iHvzto3LLYI&list=FLYKolLcvVjavQN64-gRP9Sg
#
# - No canal bomberpooper https://www.youtube.com/user/bomberpooper/channels, que vale ser estudadas também.

# %% [markdown]
# ## bomberpooper

# %% [markdown]
# Id do canal - UCKZK9dkmEba9MsGIfZ1kYjg

# %%
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime

# %%
#configurar o api

api_key = ""

from googleapiclient.discovery import build
youtube = build("youtube", "v3", developerKey=api_key)

# %%
# Id = UCKZK9dkmEba9MsGIfZ1kYjg

#contentDetails_carlosb
contentDetails_bomberpooper = youtube.channels().list(id = "UCKZK9dkmEba9MsGIfZ1kYjg", part = "contentDetails").execute()

#topicDetails_carlosb
##topicDetails_carlosb = youtube.channels().list(id = "UCBrntWupyTRnnsRy3dA4VdA", part = "topicDetails").execute()

#brandingSettings_carlosb
##brandingSettings_carlosb = youtube.channels().list(id = "CBrntWupyTRnnsRy3dA4VdA", part = 'brandingSettings').execute()

#snippet
#snippet_carlosb = youtube.channels().list(id = "CBrntWupyTRnnsRy3dA4VdA", part = "snippet").execute()

#statistics
##statistics_carlosb = youtube.channels().list(id = "CBrntWupyTRnnsRy3dA4VdA", part = "statistics").execute()

# %%
contentDetails_bomberpooper
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'LyfdWF9ym4-RlelJ_uZiL-KJTO8',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'RzdCFzLAH4bVaPKN_kUaoSRigHs',
#    'id': 'UCKZK9dkmEba9MsGIfZ1kYjg',
#    'contentDetails': {'relatedPlaylists': {'likes': 'LLKZK9dkmEba9MsGIfZ1kYjg',
#      'favorites': 'FLKZK9dkmEba9MsGIfZ1kYjg',
#      'uploads': 'UUKZK9dkmEba9MsGIfZ1kYjg',
#      'watchHistory': 'HL',
#      'watchLater': 'WL'}}}]}

# %%
# 'uploads': 'UCKZK9dkmEba9MsGIfZ1kYjg'

# %%
def get_channel_videos(channel_id):
    
    # get Uploads playlist id
    
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part='snippet', 
                                           maxResults=50,
                                           pageToken=next_page_token).execute()
       
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None:
            break
    
    return videos

# %%
videos = get_channel_videos("UCKZK9dkmEba9MsGIfZ1kYjg")

# %%
len(videos)
# Out:
# 292

# %%
videos[2]
# Out:
# {'kind': 'youtube#playlistItem',
#  'etag': 'yi1HcUZIL50kLh5Hq1CdGbqI5Jc',
#  'id': 'VVVLWks5ZGttRWJhOU1zR0lmWjFrWWpnLmZWOXc2SWdzUi1Z',
#  'snippet': {'publishedAt': '2020-07-10T20:00:09Z',
#   'channelId': 'UCKZK9dkmEba9MsGIfZ1kYjg',
#   'title': 'PENTAPOOP - Treta Eletricamente chocante',
# ...

# %%
for r in videos:
    print(r['snippet']['channelTitle'],
          r['snippet']['publishedAt'], 
          r['snippet']['title'], 
          r['snippet']['description'], 
          r['snippet']['position'], 
          r['snippet']['thumbnails']['default']['url'],
          "-", r['snippet']['resourceId']['videoId'], "-",
          "https://www.youtube.com/watch?v="+r['snippet']['resourceId']['videoId'], "\n")
# Out:
# bomberpooper 2020-07-31T18:25:59Z YTPBR - GarçoO̶͗͂⦿̶̪͋̈́̋͠Ӫ̵̝̞̫̺͙̆̀́̋̉̑̈́͘͝͝∅̶̈́͌̈͌͌⊗̸̼̣͍̞͛̈́͠͠ͅ⊛⓪⍟̷̡̨̻̆●̶̖͖̘̝͈̘̿̄̅̄̈́͝◦̶͙̳͕̣̘̿̔̆͂̄͘̚̕͠͠･ Q̴̧͖͕͙̂U̴̢̙͔̰̜͕̓̽̔̈́̍͝͝Ę̷̨̬̠̞̥̺̝̓̏͜Ḿ̶̘̗͌͒̓̾̎̕ ̵͇͇̲̟̜̙̮̭̑Ḽ̶̨̨̻̳̣̺̟̐̿̾ͅE̵͔̬̖̭͛Ŕ̸̡̡͎̮̻͉̯̭̗͊̏̈́̎̓̿̑̑ͅ ̴̪̰̻̕Î̸̢̝̝̫̒S̵͓̖̻̮̻̩͇̜̓͋̍̌ͅS̶̬͕̦̩͗̎̎̒̅̚O̴̞̖̝̼͎̘̰̹͛̀̕͝ ̷̩͕͈́̅É̵͍̓̋ ̶̢͔͉̗̟̱͚͝C̸̛̹̹̮̣͈̖̪̥̓̔͂O̸͙͈̪̠̳̤̞̐̊̀̃͌͘Ŗ̴̰͓͙̪̦̯̳͉͙̐̂͐̐Ņ̸̝̖̝̗̻͖͋̏̊̓̋͠O̸̖̎̓͝
# .
# Deixa o laike
# ☢ meu twitter: https://twitter.com/Bomberpooper
# ☢ meu canal alternativo: https://www.youtube.com/channel/UCMxtGs-KXvA8C8FUj3p-WZQ
#
# Musicas usadas:
# Geometry Dash - Practice Mode - Stay Inside Me
# Fonik - Altered Dimensions VIP
# Tape Dispenser - Sleepless Nights - Lost In My Fantasy
# Eternallove - LEGACY 0 https://i.ytimg.com/vi/q72ncJCMcYM/default.jpg - q72ncJCMcYM - https://www.youtube.com/watch?v=q72ncJCMcYM
#
# bomberpooper 2020-07-17T23:00:10Z YTPBR - Um astronauta cai na vila Deixa o laike
# ☢ meu twitter: https://twitter.com/Bomberpooper
# ...

# %%
# Salvar
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))

# %%
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

# %%
bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

# %%
bomberpooper.to_csv("[PD]Canal_bomberpooper31072020.csv")

# %% [markdown]
# ## Lucas乙anziĞau
#
# - id = UCL7GARNiJPYwjkfJRUZZ2Tw

# %%
#contentDetails

contentDetails_Lucas乙anziĞau = youtube.channels().list(id = "UCL7GARNiJPYwjkfJRUZZ2Tw", part = "contentDetails").execute()

# %%
videos = get_channel_videos("UCL7GARNiJPYwjkfJRUZZ2Tw")

# %%
for r in videos:
    print(r['snippet']['channelTitle'],
          r['snippet']['publishedAt'], 
          r['snippet']['title'], 
          r['snippet']['description'], 
          r['snippet']['position'], 
          r['snippet']['thumbnails']['default']['url'],
          "-", r['snippet']['resourceId']['videoId'], "-",
          "https://www.youtube.com/watch?v="+r['snippet']['resourceId']['videoId'], "\n")
# Out:
# Lucas乙anziĞau 2020-08-01T21:47:08Z Troféu Pooper   Junho de 2020 - Site Troféu pooper: http://trofeu.ddns.net/
# - Sala do Discord: https://discord.gg/qRfktjP
# - Playlist com o Top10 de Junho: https://www.youtube.com/playlist?list...
# - Planinha com os votos: https://docs.google.com/spreadsheets/...
#
# Olá comunidade pooper, hoje iremos apresentar um projeto baseado no antigo Golden Keys que será o TROFÉU POOPER.
#
# A cada mês estaremos lançando nos canais/redes sociais dos responsáveis e em grupos pooper uma votação contendo todos (ou quase todos) os poops do mês, que serão listados pela equipe (Urubak, MetaPooper, LucasZanzigau, bomberpooper), e utilizando a opção "Outros" o publico também poderá adicionar poops do mês que não estiverem listados na votação.
# Em todos os meses será aberta uma votação para se saber quais são os 10 melhores poops de cada mês, cada pessoa pode votar em até 5 poops por votação, quem puder ajudar compartilhando a votação ficamos muito agradecidos!
# ...

# %%
# Salvar
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

# %%
bomberpooper.to_csv("[PD]Canal_Lucas乙anziĞau03082020.csv")

# %% [markdown]
# ## Terraqueo C-404
#
# - id = UCZ0AOHHkgDkj2jNjVhWSccg

# %%
#contentDetails_Terraqueo C-404
contentDetails_Terraqueo_C404 = youtube.channels().list(id = "UCZ0AOHHkgDkj2jNjVhWSccg", part = "contentDetails").execute()

# %%
videos = get_channel_videos("UCZ0AOHHkgDkj2jNjVhWSccg")

# %%
# Salvar
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

# %%
bomberpooper.to_csv("[PD]Canal_Terraqueo_C404_03082020.csv")

# %% [markdown]
# ## Jubileu Joojado
#
# - id = UCPMfF31zIzrldImGIvthbdQ

# %%
#contentDetails_carlosb
contentDetails_Jubileu_Joojado = youtube.channels().list(id = "UCPMfF31zIzrldImGIvthbdQ", part = "contentDetails").execute()

# %%
videos = get_channel_videos("UCPMfF31zIzrldImGIvthbdQ")

# %%
# Salvar
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

# %%
bomberpooper.tail(1)
# Out:
#        channelTitle               publishedAt  \
# 11  Jubileu Joojado 2020-06-02 20:51:44+00:00
#
#                                                 title  \
# 11  BEM VINDO!!! BEM VINDO!!! BEM VINDO!!! BEM VIN...
#
#                       description  position  \
# 11  video no canal que e bom nada        11
#
#                                         thumbnails      videoId  \
# 11  https://i.ytimg.com/vi/sRIA0lSOKxU/default.jpg  sRIA0lSOKxU
#
#                                            link
# 11  https://www.youtube.com/watch?v=sRIA0lSOKxU

# %%
bomberpooper.to_csv("[PD]Canal_Jubileu_Joojado_03082020.csv")

# %% [markdown]
# ## 8000Bits
#
# - id = UCcJHZqsDTTQxCdRAWDzF-Kw

# %%
#contentDetails_8000Bits
contentDetails_8000Bits = youtube.channels().list(id = "UCcJHZqsDTTQxCdRAWDzF-Kw", part = "contentDetails").execute()

# %%
videos = get_channel_videos("UCcJHZqsDTTQxCdRAWDzF-Kw")

# %%
# Salvar
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

# %%
bomberpooper.tail(1)
# Out:
#     channelTitle               publishedAt      title  \
# 126     8000bits 2017-04-24 17:43:55+00:00  poopdocs³
#
#                                            description  position  \
# 126  ja fui e ja regressei!\n\n- outras partes -\nh...       126
#
#                                          thumbnails      videoId  \
# 126  https://i.ytimg.com/vi/AggSQWAUE1c/default.jpg  AggSQWAUE1c
#
#                                             link
# 126  https://www.youtube.com/watch?v=AggSQWAUE1c

# %%
bomberpooper.to_csv("[PD]Canal_8000Bits_03082020.csv")

# %% [markdown]
# ## Combine
#
# - id = UCq9OMSmL1OIYXLVe7qj7Tyg

# %%
#contentDetails_Combine
contentDetails_Combine = youtube.channels().list(id = "UCq9OMSmL1OIYXLVe7qj7Tyg", part = "contentDetails").execute()

# %%
videos = get_channel_videos("UCq9OMSmL1OIYXLVe7qj7Tyg")

# %%
# Salvar
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

# %%
bomberpooper.tail(1)
# Out:
#     channelTitle               publishedAt                              title  \
# 118      Combine 2013-02-15 15:22:36+00:00  YouTubePoopBR - A volta do ChaahC
#
#                description  position  \
# 118  Sim ele esta de volta       118
#
#                                          thumbnails      videoId  \
# 118  https://i.ytimg.com/vi/D3uh28BtvOM/default.jpg  D3uh28BtvOM
#
#                                             link
# 118  https://www.youtube.com/watch?v=D3uh28BtvOM

# %%
bomberpooper.to_csv("[PD]Canal_Combine_03082020.csv")

# %% [markdown]
# ## DogFumado 33
#
# Segundo canal do bomberpooper
#
# id = UCMxtGs-KXvA8C8FUj3p-WZQ

# %%
#contentDetails_DogFumado33
contentDetails_DogFumado33 = youtube.channels().list(id = "UCMxtGs-KXvA8C8FUj3p-WZQ", part = "contentDetails").execute()

# %%
videos = get_channel_videos("UCMxtGs-KXvA8C8FUj3p-WZQ")

# %%
# Salvar
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

# %%
bomberpooper.head(1)
# Out:
#    channelTitle               publishedAt  \
# 0  DogFumado 33 2020-07-29 13:55:36+00:00
#
#                                                title  \
# 0  Chaves andando de 4 no chão - chroma key [SOURCE]
#
#                     description  position  \
# 0  source free, use e desfrute!         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/H1tAkncJrgQ/default.jpg  H1tAkncJrgQ
#
#                                           link
# 0  https://www.youtube.com/watch?v=H1tAkncJrgQ

# %%
bomberpooper.to_csv("[PD]Canal_DogFumado33_03082020.csv")

# %% [markdown]
# ## ＰｒｏＳＫＰＯＯＰ
#
# id = UCuAzzwvW_qAz8pp1AUMJp-Q

# %%
videos = get_channel_videos("UCuAzzwvW_qAz8pp1AUMJp-Q")

# %%
# Salvar
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

# %%
bomberpooper.tail(1)
# Out:
#     channelTitle               publishedAt  \
# 784    ＰｒｏＳＫＰＯＯＰ 2013-01-23 00:19:07+00:00
#
#                                                  title  \
# 784  Carros do DayZ Arma 2 montagem: old hatchback(...
#
#                                            description  position  \
# 784  Veja em 720p\n\nEssa é uma das primeiras monta...       784
#
#                                          thumbnails      videoId  \
# 784  https://i.ytimg.com/vi/HWLwN3j-jdg/default.jpg  HWLwN3j-jdg
#
#                                             link
# 784  https://www.youtube.com/watch?v=HWLwN3j-jdg

# %%
bomberpooper.to_csv("[PD]Canal_ProSKPoop_04082020.csv")

# %% [markdown]
# # Outros Dir

# %% [markdown]
# ## India Capitalista Opressora
#
# id = UCVVIzACyJl3YOEuI0Rma2cA

# %%
videos = get_channel_videos("UCVVIzACyJl3YOEuI0Rma2cA")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

# %%
bomberpooper.tail(1)
# Out:
#                    channelTitle               publishedAt             title  \
# 16  India Capitalista Opressora 2015-04-30 00:20:16+00:00  u can chola mais
#
#                                           description  position  \
# 16  Lyrics \n\nU can chola mais!\n\nTa na nanam na...        16
#
#                                         thumbnails      videoId  \
# 16  https://i.ytimg.com/vi/k1Kd5Vyq93s/default.jpg  k1Kd5Vyq93s
#
#                                            link
# 16  https://www.youtube.com/watch?v=k1Kd5Vyq93s

# %%
bomberpooper.to_csv("[PD]Canal_Outros_India_04082020.csv")

# %% [markdown]
# ## BIROLIRO 3D
#
# id = UCXM1ZPNx97CBjDFGJqMvRSg

# %%
videos = get_channel_videos("UCXM1ZPNx97CBjDFGJqMvRSg")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

# %%
bomberpooper.head(1)
# Out:
#   channelTitle               publishedAt  \
# 0  BIROLIRO 3D 2020-07-28 08:51:04+00:00
#
#                                           title  \
# 0  The myth and legend in Turn Down for What...
#
#                                          description  position  \
# 0  Myth and legend are reunited with the sound of...         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/xnjrJTKjqFA/default.jpg  xnjrJTKjqFA
#
#                                           link
# 0  https://www.youtube.com/watch?v=xnjrJTKjqFA

# %%
bomberpooper.to_csv("[PD]Canal_Outros_Biroliro3D_04082020.csv")

# %% [markdown]
# ## Brasileirinhos
#
# id = UCBIubFOWKC-HRGxQHl4BP7g

# %%
videos = get_channel_videos("UCBIubFOWKC-HRGxQHl4BP7g")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

# %%
bomberpooper.head(1)
# Out:
#      channelTitle               publishedAt                      title  \
# 0  Brasileirinhos 2020-07-23 15:38:20+00:00  AJUDE ESSA LINDA VAQUINHA
#
#                                          description  position  \
# 0  💰💰💰 LINK DA VAQUINHA 💰💰💰\n\nhttps://www.vakinh...         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/eiFbhdm9BFU/default.jpg  eiFbhdm9BFU
#
#                                           link
# 0  https://www.youtube.com/watch?v=eiFbhdm9BFU

# %%
bomberpooper.to_csv("[PD]Canal_Outros_Brasileirinhos_04082020.csv")

# %% [markdown]
# ## Bolsonaro TV
#
# id = UCQnsO3lTUtDQLMaW997qbFA

# %%
videos = get_channel_videos("UCQnsO3lTUtDQLMaW997qbFA")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

# %%
bomberpooper.head(1)
# Out:
#    channelTitle               publishedAt  \
# 0  Bolsonaro TV 2020-07-25 15:14:31+00:00
#
#                                                title description  position  \
# 0  Bolsonaro fala pela primeira vez após vencer e...                     0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/UiYSliPhS_8/default.jpg  UiYSliPhS_8
#
#                                           link
# 0  https://www.youtube.com/watch?v=UiYSliPhS_8

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

# %%
# Out:
# [('Bolsonaro TV',
#   '2020-07-25T15:14:31Z',
#   'Bolsonaro fala pela primeira vez após vencer e testar negativo para coronavírus',
#   '',
#   0,
#   'https://i.ytimg.com/vi/UiYSliPhS_8/default.jpg',
#   'UiYSliPhS_8',
#   'https://www.youtube.com/watch?v=UiYSliPhS_8'),
#  ('Bolsonaro TV',
#   '2020-06-05T19:52:33Z',
#   'BOLSONARO CONVOCA LÍDERES RELIGIOSOS PARA FAZER ORAÇÃO EM PROL DO BRASIL',
#   'Curta o vídeo se apoia Bolsonaro\r\n\r\nSeja membro exclusivo do canal Bolsonaro TV:\r\nhttps://www.youtube.com/channel/UCQnsO3lTUtDQLMaW997qbFA/join\r\n\r\nPágina no Facebook:\r\nhttps://www.facebook.com/bolsonarotv\r\n\r\nGrupo no Facebook:\r\nhttps://www.facebook.com/groups/bolsonarotv',
#   1,
#   'https://i.ytimg.com/vi/JCplO_ZfeYE/default.jpg',
#   'JCplO_ZfeYE',
#   'https://www.youtube.com/watch?v=JCplO_ZfeYE'),
#  ('Bolsonaro TV',
#   '2020-06-05T14:37:33Z',
#   'APÓS SER AMEAÇAD0, BOLSONARO MANDA DURO RECADO AOS GRUPOS TERR0RISTAS',
# ...

# %%
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

# %%
bomberpooper.tail(1)
# Out:
#      channelTitle               publishedAt  \
# 183  Bolsonaro TV 2019-11-01 13:32:51+00:00
#
#                                                 title  \
# 183  Bolsonaro é OVACIONADO ao chegar em Ceilândia/DF
#
#                                            description  position  \
# 183  Página no Facebook:\nhttps://www.facebook.com/...       183
#
#                                          thumbnails      videoId  \
# 183  https://i.ytimg.com/vi/VlIPMlWjORQ/default.jpg  VlIPMlWjORQ
#
#                                             link
# 183  https://www.youtube.com/watch?v=VlIPMlWjORQ

# %% [markdown]
# # POOP

# %% [markdown]
# ## Wesley Pires
#
# id = UC9rlKSyEgr4AcQQa8ikOI-w

# %%
videos = get_channel_videos(" UC9rlKSyEgr4AcQQa8ikOI-w")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

# %%
# Out:
#    channelTitle               publishedAt  \
# 0  Wesley Pires 2020-06-29 07:20:55+00:00
#
#                                        title  \
# 0  YTBPR - O Cagão das Cartas - Second Phase
#
#                                          description  position  \
# 0  Depois de muitos, muitos, E MUUUUUUITOS PEDIDO...         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/Er6AUATzbCU/default.jpg  Er6AUATzbCU
#
#                                           link
# 0  https://www.youtube.com/watch?v=Er6AUATzbCU

# %%
bomberpooper.to_csv("[PD]Canal_Poop_Wesley_Pires_04082020.csv")

# %% [markdown]
# ## Bozoi
#
# id = UCn4CiMULR_v-XO8eTLvuSjQ

# %%
videos = get_channel_videos("UCn4CiMULR_v-XO8eTLvuSjQ")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#   channelTitle               publishedAt  \
# 0        Bozoi 2020-07-22 16:45:53+00:00
#
#                                   title  \
# 0  YTPBR - Doku mentario do Edin Macedo
#
#                                          description  position  \
# 0  Da um like, comente e compartilhe o video pra ...         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/_E15THBiAXw/default.jpg  _E15THBiAXw
#
#                                           link
# 0  https://www.youtube.com/watch?v=_E15THBiAXw

# %%
bomberpooper.to_csv("[PD]Canal_Poop_Bozoi_04082020.csv")

# %% [markdown]
# ## MR. GOLD POOP
#
# ID = UCAiNr2brDKsMRcumXeXYrHA

# %%
videos = get_channel_videos("UCAiNr2brDKsMRcumXeXYrHA")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#     channelTitle               publishedAt             title  \
# 0  MR. GOLD POOP 2020-07-28 17:58:21+00:00  YTPBR - INDOLORS
#
#                                          description  position  \
# 0  Este vídeo não tem o intuito de ofender nenhum...         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/_vq4_5qYe4Y/default.jpg  _vq4_5qYe4Y
#
#                                           link
# 0  https://www.youtube.com/watch?v=_vq4_5qYe4Y

# %%
bomberpooper.tail(1)
# Out:
#      channelTitle               publishedAt  \
# 38  MR. GOLD POOP 2017-12-08 01:16:04+00:00
#
#                                                 title  \
# 38  Brawl Stars Funny Moments & Glitches & Fails #...
#
#                                           description  position  \
# 38  ➝ My Nickname: • MR. GØLD • (2LCQUJUO)\n\n▂▃▂▃...        38
#
#                                         thumbnails      videoId  \
# 38  https://i.ytimg.com/vi/APonE1s3M20/default.jpg  APonE1s3M20
#
#                                            link
# 38  https://www.youtube.com/watch?v=APonE1s3M20

# %%
bomberpooper.to_csv("[PD]Canal_Poop_MR_GOLD_04082020.csv")

# %% [markdown]
# ## Random Pooper
#
# ID = UC0a8svvahayvUn8eH6kbwZA

# %%
videos = get_channel_videos("UC0a8svvahayvUn8eH6kbwZA")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#     channelTitle               publishedAt                 title  \
# 0  Random Pooper 2020-07-05 01:59:43+00:00  Esse é o NOSSO curso
#
#                                          description  position  \
# 0  Essa é só uma zueira ao toletorando. Nada dema...         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/ngH8Sm4aEoo/default.jpg  ngH8Sm4aEoo
#
#                                           link
# 0  https://www.youtube.com/watch?v=ngH8Sm4aEoo

# %%
bomberpooper.to_csv("[PD]Canal_Poop_RandomPooper_04082020.csv")

# %% [markdown]
# ## Alberi Junior
#
# ID = UCWYnN57DQVSZfbu6lboAzUA

# %%
videos = get_channel_videos("UCWYnN57DQVSZfbu6lboAzUA")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#     channelTitle               publishedAt  \
# 0  Alberi Junior 2020-08-01 12:26:34+00:00
#
#                                                title    description  position  \
# 0  JOGANDO AMONG US (Feat. Cabeça de Teia) DEPOIS...  Divulga ae!!!         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/gJfRmUJ9zSw/default.jpg  gJfRmUJ9zSw
#
#                                           link
# 0  https://www.youtube.com/watch?v=gJfRmUJ9zSw

# %%
bomberpooper.to_csv("[PD]Canal_Poop_AlberiJunior_04082020.csv")

# %% [markdown]
# ## CeiferTroll
#
# ID = UCnMr0-XcW3U65210N7RLOTw

# %%
videos = get_channel_videos("UCnMr0-XcW3U65210N7RLOTw")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#   channelTitle               publishedAt                      title  \
# 0  CeiferTroll 2020-07-30 13:58:33+00:00  VALORANT - CURA POR FAVOR
#
#                                          description  position  \
# 0  ✖  EI, GOSTOU DESSE VÍDEO? MOSTRA PRA ALGUM AM...         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/5o4nQ9AI5HQ/default.jpg  5o4nQ9AI5HQ
#
#                                           link
# 0  https://www.youtube.com/watch?v=5o4nQ9AI5HQ

# %%
bomberpooper.to_csv("[PD]Canal_Poop_CeiferTroll_04082020.csv")

# %% [markdown]
# ## Rosinha YTP
#
# ID = UChhG6GlS2YrOAvifjFSlkbg

# %%
videos = get_channel_videos("UChhG6GlS2YrOAvifjFSlkbg")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#   channelTitle               publishedAt            title description  \
# 0  Rosinha YTP 2020-07-31 05:46:50+00:00  - YTPBR - PEDRA
#
#    position                                      thumbnails      videoId  \
# 0         0  https://i.ytimg.com/vi/Wz-dNLfqMrA/default.jpg  Wz-dNLfqMrA
#
#                                           link
# 0  https://www.youtube.com/watch?v=Wz-dNLfqMrA

# %%
bomberpooper.to_csv("[PD]Canal_Poop_RosinhaYTP_04082020.csv")

# %% [markdown]
# ## VINI POOP
#
# ID = UCpZILNc89CYWoeTZYuiSy1A

# %%
videos = get_channel_videos("UCpZILNc89CYWoeTZYuiSy1A")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#   channelTitle               publishedAt                             title  \
# 0    VINI POOP 2020-07-23 20:00:14+00:00  YTPBR - Sitio do Pikau Taraadaum
#
#   description  position                                      thumbnails  \
# 0                     0  https://i.ytimg.com/vi/WaxPwdzIzC4/default.jpg
#
#        videoId                                         link
# 0  WaxPwdzIzC4  https://www.youtube.com/watch?v=WaxPwdzIzC4

# %%
bomberpooper.to_csv("[PD]Canal_Poop_VINIPOOP_04082020.csv")

# %% [markdown]
# ## Cabeça De Teia
#
# ID = UC8Axd5KmSx8_-4jGcerv6eA

# %%
videos = get_channel_videos("UC8Axd5KmSx8_-4jGcerv6eA")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#      channelTitle               publishedAt      title  \
# 0  Cabeça De Teia 2020-07-31 23:17:41+00:00  OCULT DAY
#
#                                          description  position  \
# 0  OCULT DAY - MELHORES CLIPES\n\nSaindo um pouco...         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/miuLMkTtAaI/default.jpg  miuLMkTtAaI
#
#                                           link
# 0  https://www.youtube.com/watch?v=miuLMkTtAaI

# %%
bomberpooper.to_csv("[PD]Canal_Poop_CabeçaDeTeia_04082020.csv")

# %% [markdown]
# ## Hiro Azz™
#
# ID = UC6cT7HDMUk_cq50W6u3zY6Q

# %%
videos = get_channel_videos("UC6cT7HDMUk_cq50W6u3zY6Q")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#   channelTitle               publishedAt                        title  \
# 0    Hiro Azz™ 2020-07-05 01:28:25+00:00  Music Racer - Wild Thoughts
#
#                                          description  position  \
# 0  ▬▬▬▬▬▬▬▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬▬▬▬▬▬▬▬▬▬\n▓▓▓▒▒▒░░░ LEIA ...         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/iTZ4RNwn2GU/default.jpg  iTZ4RNwn2GU
#
#                                           link
# 0  https://www.youtube.com/watch?v=iTZ4RNwn2GU

# %%
bomberpooper.to_csv("[PD]Canal_Poop_HiroAzz_04082020.csv")

# %% [markdown]
# ## THE JOOJ
#
# ID = UCMPh46pb-14LRd_ruglPRIQ

# %%
videos = get_channel_videos("UCMPh46pb-14LRd_ruglPRIQ")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#   channelTitle               publishedAt  \
# 0     THE JOOJ 2020-05-17 19:11:45+00:00
#
#                                   title  \
# 0  YTPBR - LIVE DAS CONVERSAS ESTRANHAS
#
#                                          description  position  \
# 0  Eae pessoal espero que curtam esse poop, não e...         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/CLHWAwGOBZ0/default.jpg  CLHWAwGOBZ0
#
#                                           link
# 0  https://www.youtube.com/watch?v=CLHWAwGOBZ0

# %%
bomberpooper.to_csv("[PD]Canal_Poop_THEJOOJ_04082020.csv")

# %% [markdown]
# ## Rarirama
#
# id = UCu05MzgvbJc-OelHNVA4ing

# %%
videos = get_channel_videos("UCu05MzgvbJc-OelHNVA4ing")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#   channelTitle               publishedAt  \
# 0     Rarirama 2019-11-23 21:05:28+00:00
#
#                                                title description  position  \
# 0  João Amorim - Obrigado a Matar but with Half-L...     sla men         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/2sB_inR4rIs/default.jpg  2sB_inR4rIs
#
#                                           link
# 0  https://www.youtube.com/watch?v=2sB_inR4rIs

# %%
bomberpooper.to_csv("[PD]Canal_Poop_Rarirama_04082020.csv")

# %% [markdown]
# ## Tolezuando
#
# ID = UCaHbHdIR12eWgf67vN74fRw

# %%
videos = get_channel_videos("UCaHbHdIR12eWgf67vN74fRw")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#   channelTitle               publishedAt  \
# 0   Tolezuando 2020-07-31 17:18:07+00:00
#
#                                                title  \
# 0  É PRA ISSO QUE EU ROUBO A INTERNET DA VIZINHA #11
#
#                                          description  position  \
# 0  Tente não rir com os vídeos mais engraçados qu...         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/YTeb-1nJBa0/default.jpg  YTeb-1nJBa0
#
#                                           link
# 0  https://www.youtube.com/watch?v=YTeb-1nJBa0

# %%
bomberpooper.to_csv("[PD]Canal_Poop_Tolezuando_04082020.csv")

# %% [markdown]
# ## MetaPooper
# ID = UCINfEvYCizPzLEBEBG2z4kA

# %%
videos = get_channel_videos("UCINfEvYCizPzLEBEBG2z4kA")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#   channelTitle               publishedAt                          title  \
# 0   MetaPooper 2020-08-01 21:11:32+00:00  Troféu Pooper - Junho de 2020
#
#                                          description  position  \
# 0  - Discord do TroféuPooper: https://discord.gg/...         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/MgzvTqWQ2ug/default.jpg  MgzvTqWQ2ug
#
#                                           link
# 0  https://www.youtube.com/watch?v=MgzvTqWQ2ug

# %%
bomberpooper.to_csv("[PD]Canal_Poop_MetaPooper_05082020.csv")

# %% [markdown]
# ## MegaPoops
#
# ID = UCnLEkfvDEqbVmvbSSJZtdtw

# %%
videos = get_channel_videos("UCnLEkfvDEqbVmvbSSJZtdtw")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#   channelTitle               publishedAt                     title  \
# 0    MegaPoops 2020-08-04 20:42:47+00:00  YTPBR - Simplesmente pão
#
#                                          description  position  \
# 0  Eu sei que ta ruim não precisa reclamar nos co...         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/7GGY2-TowbU/default.jpg  7GGY2-TowbU
#
#                                           link
# 0  https://www.youtube.com/watch?v=7GGY2-TowbU

# %%
bomberpooper.to_csv("[PD]Canal_Poop_MegaPoops_05082020.csv")

# %% [markdown]
# ## pooper DOIDÃO
#
# ID = UCEhSJM01Qs7eZbRs8Eoq3Jg

# %%
videos = get_channel_videos("UCEhSJM01Qs7eZbRs8Eoq3Jg")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#     channelTitle               publishedAt                title  \
# 0  pooper DOIDÃO 2020-06-08 16:53:37+00:00  Fechamento do canal
#
#                                          description  position  \
# 0  link do novo canal: https://www.youtube.com/ch...         0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/oFGTjGYnuiw/default.jpg  oFGTjGYnuiw
#
#                                           link
# 0  https://www.youtube.com/watch?v=oFGTjGYnuiw

# %%
bomberpooper.to_csv("[PD]Canal_Poop_pooperDOIDÃO_05082020.csv")

# %% [markdown]
# ## Beta Poop
#
# ID = UC0taaIaWERXZPWMxuvFN-xg

# %%
videos = get_channel_videos("UC0taaIaWERXZPWMxuvFN-xg")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#   channelTitle               publishedAt  \
# 0    Beta Poop 2020-08-05 00:30:28+00:00
#
#                                       title description  position  \
# 0  YTPBR - SKYLAB E O AWAY TROCANDO UM LERO                     0
#
#                                        thumbnails      videoId  \
# 0  https://i.ytimg.com/vi/qF70s0MmdG8/default.jpg  qF70s0MmdG8
#
#                                           link
# 0  https://www.youtube.com/watch?v=qF70s0MmdG8

# %%
bomberpooper.to_csv("[PD]Canal_Poop_BetaPoop_05082020.csv")

# %% [markdown]
# ## faustãσ illuminΔti
#
# ID = UCZS7sfA2x3nLepRUagikvAA

# %%
videos = get_channel_videos("UCZS7sfA2x3nLepRUagikvAA")

# %%
bomberpooper = []

for r in videos:
    channelTitle =  r['snippet']['channelTitle']
    publishedAt = r['snippet']['publishedAt'] 
    title = r['snippet']['title']
    description = r['snippet']['description'] 
    position = r['snippet']['position'] 
    thumbnails = r['snippet']['thumbnails']['default']['url']
    videoId = r['snippet']['resourceId']['videoId']
    link = "https://www.youtube.com/watch?v=" +r['snippet']['resourceId']['videoId']
    bomberpooper.append((channelTitle, publishedAt, title, description, position, thumbnails, videoId, link))
    
bomberpooper = pd.DataFrame(bomberpooper, columns=['channelTitle', 'publishedAt', 'title', 'description', 'position', 'thumbnails', 'videoId', 'link'])

bomberpooper.publishedAt = pd.to_datetime(bomberpooper.publishedAt)

bomberpooper.head(1)
# Out:
#          channelTitle               publishedAt                       title  \
# 0  faustãσ illuminΔti 2019-05-04 20:35:05+00:00  reforma da previdencia.exe
#
#    description  position                                      thumbnails  \
# 0  cenas reais         0  https://i.ytimg.com/vi/GbTmZVeF0Lw/default.jpg
#
#        videoId                                         link
# 0  GbTmZVeF0Lw  https://www.youtube.com/watch?v=GbTmZVeF0Lw

# %%
bomberpooper.to_csv("[PD]Canal_Poop_faustAOIlluminAti_05082020.csv")
